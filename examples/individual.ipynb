# %%
from mhm.individual import Individual
import pandas as pd
import numpy as np

# %%
# parameters for generating the population
# NB: to separate categrical columns from the rest, values of categoricals should be strings

## age
# # No need to create the exact ages
# def create_age_distribution(ages: np.array, p:np.array):
#     """Create age distribution based on age group distribution.
    
#     Assumption here is that within a group, age distributions are uniformed.

#     Args:
#         ages (np.array): _description_
#         n_groups (int): _description_
#         p (np.array): _description_
#     """
#     groups = np.array_split(np.array(ages), p.size)
#     group_sizes = [g.size for g in groups]
#     prop_per_group = p / group_sizes
#     return np.repeat(prop_per_group, group_sizes)
    
# min_age = 24
# max_age = 65
# props_age_groups = np.array([.25, .23, .31, .21])

# ages = np.arange(min_age, max_age + 1)
# age = (
#     ages, 
#     create_age_distribution(ages, props_age_groups)
# )   

age_group = (
    ['_1', '_2', '_3', '_4'], 
    [.25, .23, .31, .21]
)

gender = (
    [0, 1],
    [.5, .5]    
)

education = (
    ['Low', 'Medium', 'High'], 
    [.11, .25, .64]
)

employed = (
    ['No, other', 'No, seeking employment', 'Yes'], 
    [.76, .155, .085]
)

partnership_status = (
    ['Singe', 'Married', 'Live-in partner', 'In relationship, no cohabitation', 'Other'],
    [.2, .41, .29, .09, .01]    
)

pre_existing_depression = (
    [0, 1], # false, true
    [.8, .2]
)

pre_existing_burnout = (
    [0, 1], # false, true
    [.27, .73]
)

pre_existing_addiction = (
    [0, 1], # false, true
    [.95, .05]
)

pre_existing_chronic_fatigue = (
    [0, 1], # false, true
    [.95, .05]
)

parenthood = (
    [0, 1], # no child, single parent, complete parents
    [.93, .07]
)

living_with_child = (
    [0, 1], 
    [.42, .58]
)

single_parent = (
    [0, 1], 
    [.95, .05]
)

housing_difficulties = (
    ['No', 'Some', 'Many'], 
    [0.79, 0.18, 0.03]
)

finance_difficulties = (
    ['No', 'Some', 'Many'], 
    [.75, .13, .12]
)

pre_existing_health_issues = (
    ['No', 'Some', 'Many'], 
    [.65, .20, .15]
)

partner_difficulties = (
    ['No', 'Some', 'Many', 'Other'], 
    [.67, .18, .05, .1]
)

job_type = (
    ['white_collar', 'medical_professional', 'key_worker', 'other_job'], 
    [.2, .2, .2, .4]
)

area = (
    ['urban', 'rural'], 
    [.7, .3]
)

ses = (
    ['low', 'medium', 'high'], 
    [.15, .55, .3]
)

# %%
# demo usage of the populate method
size = 100
seed = 1
Individual.populate(size, seed, 
        gender=gender, 
        age_group=age_group, 
        education=education, 
        employed=employed, 
        partnership_status=partnership_status, 
        pre_existing_depression=pre_existing_depression, 
        pre_existing_burnout=pre_existing_burnout, 
        pre_existing_addiction=pre_existing_addiction, 
        pre_existing_chronic_fatigue=pre_existing_chronic_fatigue, 
        parenthood=parenthood, 
        living_with_child=living_with_child, 
        single_parent=single_parent, 
        housing_difficulties=housing_difficulties, 
        finance_difficulties=finance_difficulties, 
        pre_existing_health_issues=pre_existing_health_issues, 
        partner_difficulties=partner_difficulties, 
        job_type=job_type, 
        area=area, 
        ses=ses
        )

# %%
# Plots of distributions
# Note: that the features variable should be fully encapsulated in the class
#       and thus should not be visited like this.
Individual._features.hist(grid=False, figsize=(15, 40), layout=(11, 4))
# Out:
# array([[<Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'pre_existing_depression'}>,
#         <Axes: title={'center': 'pre_existing_burnout'}>,
#         <Axes: title={'center': 'pre_existing_addiction'}>],
#        [<Axes: title={'center': 'pre_existing_chronic_fatigue'}>,
#         <Axes: title={'center': 'parenthood'}>,
#         <Axes: title={'center': 'living_with_child'}>,
#         <Axes: title={'center': 'single_parent'}>],
#        [<Axes: title={'center': 'age_group__1'}>,
#         <Axes: title={'center': 'age_group__2'}>,
#         <Axes: title={'center': 'age_group__3'}>,
#         <Axes: title={'center': 'age_group__4'}>],
#        [<Axes: title={'center': 'education_High'}>,
#         <Axes: title={'center': 'education_Low'}>,
#         <Axes: title={'center': 'education_Medium'}>,
#         <Axes: title={'center': 'employed_No, other'}>],
#        [<Axes: title={'center': 'employed_No, seeking employment'}>,
#         <Axes: title={'center': 'employed_Yes'}>,
#         <Axes: title={'center': 'partnership_status_In relationship, no cohabitation'}>,
#         <Axes: title={'center': 'partnership_status_Live-in partner'}>],
#        [<Axes: title={'center': 'partnership_status_Married'}>,
#         <Axes: title={'center': 'partnership_status_Singe'}>,
#         <Axes: title={'center': 'housing_difficulties_Many'}>,
#         <Axes: title={'center': 'housing_difficulties_No'}>],
#        [<Axes: title={'center': 'housing_difficulties_Some'}>,
#         <Axes: title={'center': 'finance_difficulties_Many'}>,
#         <Axes: title={'center': 'finance_difficulties_No'}>,
#         <Axes: title={'center': 'finance_difficulties_Some'}>],
#        [<Axes: title={'center': 'pre_existing_health_issues_Many'}>,
#         <Axes: title={'center': 'pre_existing_health_issues_No'}>,
#         <Axes: title={'center': 'pre_existing_health_issues_Some'}>,
#         <Axes: title={'center': 'partner_difficulties_Many'}>],
#        [<Axes: title={'center': 'partner_difficulties_No'}>,
#         <Axes: title={'center': 'partner_difficulties_Other'}>,
#         <Axes: title={'center': 'partner_difficulties_Some'}>,
#         <Axes: title={'center': 'job_type_key_worker'}>],
#        [<Axes: title={'center': 'job_type_medical_professional'}>,
#         <Axes: title={'center': 'job_type_other_job'}>,
#         <Axes: title={'center': 'job_type_white_collar'}>,
#         <Axes: title={'center': 'area_rural'}>],
#        [<Axes: title={'center': 'area_urban'}>,
#         <Axes: title={'center': 'ses_high'}>,
#         <Axes: title={'center': 'ses_low'}>,
#         <Axes: title={'center': 'ses_medium'}>]], dtype=object)

# %%
individuals = []
for i in range(size):
    individuals.append(Individual(i))
    
individuals[0].get_features()
# Out:
# gender                                                 0
# pre_existing_depression                                0
# pre_existing_burnout                                   1
# pre_existing_addiction                                 0
# pre_existing_chronic_fatigue                           0
# parenthood                                             0
# living_with_child                                      0
# single_parent                                          0
# age_group__1                                           0
# age_group__2                                           1
# age_group__3                                           0
# age_group__4                                           0
# education_High                                         1
# education_Low                                          0
# education_Medium                                       0
# employed_No, other                                     0
# employed_No, seeking employment                        1
# employed_Yes                                           0
# partnership_status_In relationship, no cohabitation    1
# partnership_status_Live-in partner                     0
# partnership_status_Married                             0
# partnership_status_Singe                               0
# housing_difficulties_Many                              0
# housing_difficulties_No                                0
# housing_difficulties_Some                              1
# finance_difficulties_Many                              0
# finance_difficulties_No                                1
# finance_difficulties_Some                              0
# pre_existing_health_issues_Many                        0
# pre_existing_health_issues_No                          1
# pre_existing_health_issues_Some                        0
# partner_difficulties_Many                              0
# partner_difficulties_No                                1
# partner_difficulties_Other                             0
# partner_difficulties_Some                              0
# job_type_key_worker                                    0
# job_type_medical_professional                          0
# job_type_other_job                                     0
# job_type_white_collar                                  1
# area_rural                                             0
# area_urban                                             1
# ses_high                                               1
# ses_low                                                0
# ses_medium                                             0
# Name: 0, dtype: int64
