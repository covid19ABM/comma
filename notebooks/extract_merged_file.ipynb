# %%
import pandas as pd
import os

# %%
os.chdir('../')
dir_params =os.path.join(os.getcwd(),'parameters')

# %%
xlsx = pd.ExcelFile('parameters/merged_file.xlsx')
sheets = xlsx.sheet_names
for sheet in sheets:
    df = pd.read_excel(xlsx, sheet, index_col=0)
    df.to_csv(f'parameters_reg_19June/{sheet}.csv', index=False, sep=';')
